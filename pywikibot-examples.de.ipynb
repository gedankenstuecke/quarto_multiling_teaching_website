# %% [markdown]
# # Wie eins `pywikibot` nutzen kann
#
# Wir laden die Programmbibliothek, überprüfen dass der Nutzername korrekt gesetzt wurde um die API limits für unseren Nutzendenaccount einzuhalten. Der Nutzername wird aus `user-config.py` im gleichen Ordner wie dieses Notebook gelesen. Die Konfigurationsdatei kann über `pwb generate_user_files` generiert werden
#
# ## Konfiguration

# %%
import pywikibot
import pandas as pd
pywikibot.config.usernames
# Out:
# defaultdict(dict, {'wikipedia': {'en': 'Gedankenstuecke'}, 'wikidata': {}})

# %% [markdown]
# Falls ein Nutzername für die gewählte Sprachedition von Wikipedia erscheint ist alles okay!
#
# ## Alle Wikipedia-Seiten für kenianische Politiker abrufen (basierend auf der Kategorie)
#
# Mit `recurse=True` finden wir auch alle Seiten die in Subkategorien sind. Hier nutzen wir `Category:Kenyan_politicians` als Startkategorie:

# %%
site = pywikibot.Site('en', 'wikipedia') # select the wikimedia project we want to interact with

politician_pages = [] # to store page names and handles after iterating over category
category = pywikibot.Category(site, "Kenyan_politicians") # select category

for i in category.articles(recurse=True):
    politician_pages.append(i)

# %%
print("There are {} pages in the 'Kenyan politicians' category".format(len(politician_pages)))
# Out:
# There are 933 pages in the 'Kenyan politicians' category

# %% [markdown]
# ## Getting a single page
#
# Let's use a single page as an example to explore what else we can easily get from the API.

# %%
page = politician_pages[0]
page.title()
# Out:
# 'Abdilatif Abdalla'

# %% [markdown]
# We can now access the latest version of the article:

# %%
page.text[:2000]
# Out:
# '{{short description|Kenyan writer and political activist}}\n{{Use dmy dates|date=April 2022}}\n\'\'\'Abdilatif Abdalla\'\'\' (born 1946 in [[Mombasa]]) is a Kenyan writer and political activist. He was imprisoned for his support of the [[Kenya People\'s Union]], and began writing poetry in [[solitary confinement]]. A collection of poems from this time were published as a book titled \'\'Sauti ya Dhiki\'\'{{efn|"Voice of Agony"}} (1973), which was awarded the [[Jomo Kenyatta Prize for Literature]].\n\n==Early life==\nAbdilatif Abdalla was born in [[Mombasa]], [[Kenya]], in 1946, where he was brought up by his grandfather Ahmad Basheikh bin Hussein. Abdalla attended school in [[Faza]], before undertaking further studies at the British Tutorial College. He began his political involvement after working for the Mombasa City Council as an assistant [[accountant]], writing the pamphlet \'\'Kenya Twendapi?\'\' (Eng: \'\'Kenya, Where Are We Headed\'\') in support of the [[Kenya People\'s Union]] in 1968.{{sfn |Akyeampong|Gates| 2012| pp=17-18}}<ref name="Pambazuka">{{cite news|last1=wa Wanjiru|first1=Kimani|title=Abdilatif Abdalla: \'My poems gave me company\'|url=http://www.pambazuka.org/arts/abdilatif-abdalla-my-poems-gave-me-company|access-date=20 October 2016|work=Pambazuka News|date=14 October 2010}}</ref>\n\n==Political imprisonment and writing==\nWhen the Kenyan Government of [[Jomo Kenyatta]] conducted a crackdown on KPU activists, Abdalla was imprisoned for conspiracy between 1969 and 1972. He was at first held in [[Kamiti Maximum Security Prison|Kamiti Prison]], and later in [https://kituochasheria.or.ke/shimo-la-tewa-mens-justice-centre/ Shimo la Tewa Prison], where he was kept in solitary confinement. It was while imprisoned that he wrote the poems that would be collected in the 1973 work \'\'Sauti ya Dhiki\'\', whose title translates to "Voice of Agony". These were written in the Mombasa version of the [[Swahili language]]{{sfn |Akyeampong|Gates| 2012| pp=17-18}} and published by his older broth'

# %% [markdown]
# ## Exploring categories a page belongs to
#
# We can now see if or to which other category pages this page belongs, e.g. if we'd use this to expand our serach

# %%
for c in page.categories():
    print(c)
# Out:
# [[en:Category:1946 births]]
# [[en:Category:Academic staff of Leipzig University]]
# [[en:Category:Academic staff of the University of Dar es Salaam]]
# [[en:Category:Articles with short description]]
# [[en:Category:BBC people]]
# [[en:Category:Kenyan male writers]]
# [[en:Category:Kenyan politicians]]
# [[en:Category:Kenyan writers]]
# [[en:Category:Living people]]
# [[en:Category:People associated with SOAS University of London]]
# [[en:Category:People from Mombasa]]
# [[en:Category:Short description is different from Wikidata]]
# [[en:Category:Swahili-language writers]]
# [[en:Category:Use dmy dates from April 2022]]

# %% [markdown]
# ## Authorship
#
# To check how authorship for the current text status distributes across users we can do the following. Each tupel of the form `(1234, 50.0)` gives the authorship in character count (`1234`) and percentage of the article `(50.0`)

# %%
page.authorship()
# Out:
# {'Miyagawa': (2195, 52.0),
#  'Gaudio': (759, 18.0),
#  '2A02:8070:D1AC:E500:D480:B9B7:2A33:B6F6': (295, 7.0),
#  'Vysotsky': (253, 6.0),
#  'IOHANNVSVERVS': (168, 4.0)}

# %% [markdown]
# Now we can check how many revisions there were:

# %%
page.revision_count()
# Out:
# 46

# %% [markdown]
# We can also explore the different revisions, when they were made, by whom and the edit-comment that was left

# %%
for i in page.revisions():
    print("{} edited the article on {} with this edit comment: {}".format(i['user'], i['timestamp'], i['comment']))
# Out:
# Almaddy2022 edited the article on 2025-04-14T10:08:57Z with this edit comment:
# Almaddy2022 edited the article on 2025-04-06T12:24:59Z with this edit comment: /* Political imprisonment and writing */ I have added links of Kimati Prison and Shimo la Tewa
# Inter&anthro edited the article on 2024-08-23T20:59:25Z with this edit comment: mentioned and sourced in the article
# IOHANNVSVERVS edited the article on 2024-03-27T06:08:59Z with this edit comment: /* Political imprisonment and writing */ce
# IOHANNVSVERVS edited the article on 2024-03-27T06:08:39Z with this edit comment: /* References */
# IOHANNVSVERVS edited the article on 2024-03-27T06:07:52Z with this edit comment: /* Political imprisonment and writing */Voices of Agony
# IOHANNVSVERVS edited the article on 2024-03-27T06:06:57Z with this edit comment: /* Political imprisonment and writing */correct date
# IOHANNVSVERVS edited the article on 2024-03-27T06:05:52Z with this edit comment: copyedit lead
# IOHANNVSVERVS edited the article on 2024-03-27T05:51:44Z with this edit comment: /* External links */+Wikiquote
# 96.106.43.35 edited the article on 2023-02-17T13:39:54Z with this edit comment: Undid revision 1139908556 by [[Special:Contributions/196.202.223.224|196.202.223.224]] ([[User talk:196.202.223.224|talk]])
# 196.202.223.224 edited the article on 2023-02-17T13:39:38Z with this edit comment: added more detail
# JJMC89 bot III edited the article on 2023-02-08T12:22:49Z with this edit comment: Moving [[:Category:University of Dar es Salaam faculty]] to [[:Category:Academic staff of the University of Dar es Salaam]] per [[Wikipedia:Categories for discussion/Log/2023 January 29#Academic staff in Africa and Asia]]
# JJMC89 bot III edited the article on 2023-01-12T08:40:17Z with this edit comment: Moving [[:Category:Leipzig University faculty]] to [[:Category:Academic staff of Leipzig University]] per [[Wikipedia:Categories for discussion/Log/2023 January 3]]
# BrownHairedGirl edited the article on 2022-04-13T04:59:24Z with this edit comment: add {{[[Template:Use dmy dates|Use dmy dates]]}}
# SdkbBot edited the article on 2022-01-20T21:53:24Z with this edit comment: Removed [[MOS:OVERLINK|overlinked]] country wikilink and [[WP:GENFIX|general fixes]] ([[Wikipedia:Bots/Requests_for_approval/SdkbBot_2|task 2]])
# Citation bot edited the article on 2021-04-08T19:30:22Z with this edit comment: Removed parameters. | [[WP:UCB|Use this bot]]. [[WP:DBUG|Report bugs]]. | Suggested by Jonesey95 | via #UCB_webform 58/3000
# Simeon edited the article on 2020-07-17T08:36:04Z with this edit comment: Adding local [[Wikipedia:Short description|short description]]: "Kenyan writer and political activist", overriding Wikidata description "Kenyan poet and University teacher" ([[Wikipedia:Shortdesc helper|Shortdesc helper]])
# 2A02:8070:D1AC:E500:D480:B9B7:2A33:B6F6 edited the article on 2020-03-30T09:55:02Z with this edit comment: /* Political imprisonment and writing */
# 2A02:8070:D1AC:E500:D480:B9B7:2A33:B6F6 edited the article on 2020-03-30T09:54:34Z with this edit comment: inserted a new edited volume in the reference
# 75.188.45.156 edited the article on 2020-02-11T19:16:54Z with this edit comment: /* Political imprisonment and writing */
# Jevansen edited the article on 2019-12-30T06:48:59Z with this edit comment: Moving from [[Category:People associated with SOAS, University of London]] to [[Category:People associated with SOAS University of London]] using [[c:Help:Cat-a-lot|Cat-a-lot]]
# Ser Amantio di Nicolao edited the article on 2019-11-21T22:43:44Z with this edit comment: Copying from [[Category:Kenyan writers]] to [[Category:Kenyan male writers]] using [[c:Help:Cat-a-lot|Cat-a-lot]]
# 79.178.31.23 edited the article on 2018-05-03T13:48:10Z with this edit comment: /* Early life */
# InternetArchiveBot edited the article on 2017-06-25T03:16:07Z with this edit comment: Rescuing 1 sources and tagging 0 as dead. #IABot (v1.4beta3)
# Materialscientist edited the article on 2016-12-16T11:33:16Z with this edit comment: Reverted 1 edit by [[Special:Contributions/Abdiladif33|Abdiladif33]] identified as test/vandalism using [[WP:STiki|STiki]]
# Abdiladif33 edited the article on 2016-12-16T10:19:34Z with this edit comment:
# Miyagawa edited the article on 2016-10-21T09:38:54Z with this edit comment: /* Political prisoner and writing */ Copyedit section title
# Miyagawa edited the article on 2016-10-20T20:48:54Z with this edit comment: Expanded
# Miyagawa edited the article on 2016-10-20T20:43:28Z with this edit comment: Begun expansion
# InternetArchiveBot edited the article on 2016-10-02T11:19:27Z with this edit comment: Rescuing 1 sources and tagging 0 as dead. #IABot (v1.2.4)
# KasparBot edited the article on 2016-05-22T01:25:07Z with this edit comment: migrating [[Wikipedia:Persondata|Persondata]] to Wikidata, [[toollabs:kasparbot/persondata/|please help]], see [[toollabs:kasparbot/persondata/challenge.php/article/Abdilatif Abdalla|challenges for this article]]
# KasparBot edited the article on 2015-04-26T23:16:36Z with this edit comment: authority control moved to wikidata
# GoodDay edited the article on 2015-01-12T01:05:45Z with this edit comment: Intro
# Vysotsky edited the article on 2014-11-06T09:22:11Z with this edit comment: Category
# Vysotsky edited the article on 2014-11-06T09:19:45Z with this edit comment:
# Vysotsky edited the article on 2014-11-06T08:57:18Z with this edit comment: /* References and external links */
# Addbot edited the article on 2013-02-28T10:50:12Z with this edit comment: [[User:Addbot|Bot:]] Migrating 4 interwiki links, now provided by [[Wikipedia:Wikidata|Wikidata]] on [[d:q308189]] ([[User talk:Addbot|Report Errors]])
# Dsp13 edited the article on 2012-12-03T10:16:31Z with this edit comment: authority control
# SwisterTwister edited the article on 2012-04-06T20:30:31Z with this edit comment: +category
# Bgwhite edited the article on 2012-04-03T20:33:44Z with this edit comment: /* References and external links */Add info to [[Wikipedia:Persondata]] using [[Project:AWB|AWB]] (8032)
# KConWiki edited the article on 2012-03-31T17:53:14Z with this edit comment:
# KConWiki edited the article on 2012-03-31T17:52:44Z with this edit comment: /* References and external links */
# Hmains edited the article on 2012-03-30T21:23:38Z with this edit comment: copyedit, clarity edits, MOS implementation, and/or AWB general fixes using [[Project:AWB|AWB]]
# ZéroBot edited the article on 2012-03-30T07:46:57Z with this edit comment: r2.7.1) (Robot: Adding [[fr:Abdilatif Abdalla]]
# ZéroBot edited the article on 2012-03-30T07:45:09Z with this edit comment: r2.7.1) (Robot: Adding [[es:Abdilatif Abdalla]], [[gl:Abdilatif Abdalla]]; removing: [[fr:Abdilatif Abdalla]]
# Gaudio edited the article on 2012-03-30T07:43:56Z with this edit comment: [[WP:AES|←]]Created page with ''''Abdilatif Abdalla''' ([[Mombasa]] [[1946]]) [[Kenya]]n writer and politician.   He worked in [[Mombasa]] Council and after his publication of a pamphlet where...'

# %% [markdown]
# Looking carefully, you'll see that there are authors named which aren't listed as the current `authorship` marks. To see all contributors, even if no text of them is in the latest version, we can use:

# %%
page.contributors()
# Out:
# Counter({'IOHANNVSVERVS': 6,
#          'Miyagawa': 3,
#          'Vysotsky': 3,
#          'Almaddy2022': 2,
#          'JJMC89 bot III': 2,
#          '2A02:8070:D1AC:E500:D480:B9B7:2A33:B6F6': 2,
#          'InternetArchiveBot': 2,
#          'KasparBot': 2,
#          'KConWiki': 2,
#          'ZéroBot': 2,
#          'Inter&anthro': 1,
#          '96.106.43.35': 1,
#          '196.202.223.224': 1,
#          'BrownHairedGirl': 1,
#          'SdkbBot': 1,
#          'Citation bot': 1,
#          'Simeon': 1,
#          '75.188.45.156': 1,
#          'Jevansen': 1,
#          'Ser Amantio di Nicolao': 1,
#          '79.178.31.23': 1,
#          'Materialscientist': 1,
#          'Abdiladif33': 1,
#          'GoodDay': 1,
#          'Addbot': 1,
#          'Dsp13': 1,
#          'SwisterTwister': 1,
#          'Bgwhite': 1,
#          'Hmains': 1,
#          'Gaudio': 1})

# %% [markdown]
# ## Exploring contributors
#
# Let's now investigate a bit more details about those users:
#
# 1. how much have they edited in Wikipedia?
# 2. are they a bot? and how many of the overall editors are bots?
# 3. if they declare: what is their gender?

# %%
bot_editors = 0 # for counting bots

for i in page.contributors():
    user = pywikibot.User(site, i) # get user object to manipulate
    user_groups = user.groups()
    print("{} made {} edits, declared their gender as {} and is in these user groups {}".format(i, 
                                                                                                user.editCount(),
                                                                                                user.gender(),
                                                                                                user_groups))
    if "bot" in user_groups:
        bot_editors += 1

print("In total {} of {} editors are bots ({} %)".format(bot_editors,
                                                       len(page.contributors()),
                                                       bot_editors/len(page.contributors())
                                                      ))
# Out:
# Almaddy2022 made 883 edits, declared their gender as unknown and is in these user groups ['extendedconfirmed', '*', 'user', 'autoconfirmed']
# Inter&anthro made 89857 edits, declared their gender as unknown and is in these user groups ['extendedconfirmed', '*', 'user', 'autoconfirmed']
# IOHANNVSVERVS made 10862 edits, declared their gender as unknown and is in these user groups ['extendedconfirmed', '*', 'user', 'autoconfirmed']
# 96.106.43.35 made 0 edits, declared their gender as unknown and is in these user groups []
# 196.202.223.224 made 0 edits, declared their gender as unknown and is in these user groups []
# JJMC89 bot III made 5653001 edits, declared their gender as unknown and is in these user groups ['bot', 'sysop', '*', 'user', 'autoconfirmed']
# BrownHairedGirl made 2942733 edits, declared their gender as female and is in these user groups ['autoreviewer', 'extendedconfirmed', 'filemover', 'reviewer', 'rollbacker', '*', 'user', 'autoconfirmed']
# SdkbBot made 370790 edits, declared their gender as unknown and is in these user groups ['bot', '*', 'user', 'autoconfirmed']
# Citation bot made 6065808 edits, declared their gender as unknown and is in these user groups ['bot', '*', 'user', 'autoconfirmed']
# Simeon made 1061294 edits, declared their gender as unknown and is in these user groups ['autoreviewer', 'extendedconfirmed', '*', 'user', 'autoconfirmed']
# 2A02:8070:D1AC:E500:D480:B9B7:2A33:B6F6 made 0 edits, declared their gender as unknown and is in these user groups []
# 75.188.45.156 made 0 edits, declared their gender as unknown and is in these user groups []
# Jevansen made 5512050 edits, declared their gender as male and is in these user groups ['autoreviewer', 'extendedconfirmed', 'extendedmover', 'reviewer', 'rollbacker', '*', 'user', 'autoconfirmed']
# Ser Amantio di Nicolao made 6934234 edits, declared their gender as unknown and is in these user groups ['autoreviewer', 'sysop', '*', 'user', 'autoconfirmed']
# 79.178.31.23 made 0 edits, declared their gender as unknown and is in these user groups []
# InternetArchiveBot made 6040325 edits, declared their gender as unknown and is in these user groups ['bot', 'reviewer', '*', 'user', 'autoconfirmed']
# Materialscientist made 2075272 edits, declared their gender as unknown and is in these user groups ['abusefilter', 'autoreviewer', 'checkuser', 'rollbacker', 'sysop', '*', 'user', 'autoconfirmed']
# Abdiladif33 made 4 edits, declared their gender as unknown and is in these user groups ['*', 'user']
# Miyagawa made 57339 edits, declared their gender as male and is in these user groups ['extendedconfirmed', 'reviewer', 'rollbacker', '*', 'user', 'autoconfirmed']
# KasparBot made 1549811 edits, declared their gender as unknown and is in these user groups ['*', 'user', 'autoconfirmed']
# GoodDay made 520051 edits, declared their gender as unknown and is in these user groups ['autoreviewer', 'extendedconfirmed', 'reviewer', '*', 'user', 'autoconfirmed']
# Vysotsky made 15287 edits, declared their gender as male and is in these user groups ['extendedconfirmed', '*', 'user', 'autoconfirmed']
# Addbot made 2838809 edits, declared their gender as unknown and is in these user groups ['bot', '*', 'user', 'autoconfirmed']
# Dsp13 made 104600 edits, declared their gender as unknown and is in these user groups ['autoreviewer', 'extendedconfirmed', 'ipblock-exempt', 'reviewer', '*', 'user', 'autoconfirmed']
# SwisterTwister made 187094 edits, declared their gender as male and is in these user groups ['*', 'user', 'autoconfirmed']
# Bgwhite made 547151 edits, declared their gender as unknown and is in these user groups ['extendedconfirmed', '*', 'user', 'autoconfirmed']
# KConWiki made 198038 edits, declared their gender as male and is in these user groups ['autoreviewer', 'extendedconfirmed', '*', 'user', 'autoconfirmed']
# Hmains made 1214500 edits, declared their gender as male and is in these user groups ['autoreviewer', 'extendedconfirmed', 'reviewer', '*', 'user', 'autoconfirmed']
# ZéroBot made 704777 edits, declared their gender as unknown and is in these user groups ['*', 'user', 'autoconfirmed']
# Gaudio made 10369 edits, declared their gender as unknown and is in these user groups ['extendedconfirmed', '*', 'user', 'autoconfirmed']
# In total 5 of 30 editors are bots (0.16666666666666666 %)

# %% [markdown]
# If we want, we can also explore the other content that those editors have touched. Using a single editor as an example:

# %%
user = pywikibot.User(site, "Almaddy2022")

for page in user.contributions(total=50):
    print(page)
# Out:
# (Page('Lamu Fort Library'), 1332190871, Timestamp(2026, 1, 10, 12, 6, 14), 'I have added a citation')
# (Page('Lamu Fort Library'), 1332190768, Timestamp(2026, 1, 10, 12, 4, 47), '/* Archive section */ I have added a citation for ustadh Mau')
# (Page('Lamu Fort Library'), 1311935664, Timestamp(2025, 9, 17, 18, 50, 39), '/* Friends of the Library */ I have added a link of the friends of the library')
# (Page('Lamu Fort Library'), 1311935285, Timestamp(2025, 9, 17, 18, 47, 52), '/* Friends of the Library */ I have added a friend of library')
# (Page('Mamie Buazo'), 1298753712, Timestamp(2025, 7, 4, 13, 3, 21), 'I have added a reference on the content I have added on the short description space about her life time')
# (Page('Mamie Buazo'), 1298753164, Timestamp(2025, 7, 4, 12, 59, 20), 'I have added contents on mamie short description')
# (Page('Mamie Buazo'), 1298751050, Timestamp(2025, 7, 4, 12, 42, 44), 'I have added her childhood life of Mamie')
# (Page('Mamie Buazo'), 1298750577, Timestamp(2025, 7, 4, 12, 38, 43), 'I have added the information of the place where Mamie was born')
# (Page('Gisèle Bosimba'), 1298747254, Timestamp(2025, 7, 4, 12, 12, 50), 'I have added a reference on the Gisele article of the information about the football team')
# (Page('Gisèle Bosimba'), 1298722760, Timestamp(2025, 7, 4, 7, 40, 54), "/* International career */ I have added a link of the African Women's Championship")
# (Page('Gisèle Bosimba'), 1298722614, Timestamp(2025, 7, 4, 7, 38, 26), "/* International career */ I have added more information about African Women's Championship")
# (Page('Abdilatif Abdalla'), 1285549690, Timestamp(2025, 4, 14, 10, 8, 57), '')
# (Page('Abdilatif Abdalla'), 1284245409, Timestamp(2025, 4, 6, 12, 24, 59), '/* Political imprisonment and writing */ I have added links of Kimati Prison and Shimo la Tewa')
# (Page('User talk:Almaddy2022'), 1283735865, Timestamp(2025, 4, 3, 9, 40, 57), '/* Deletion discussion about Traditional Lime Making and uses */ Reply')
# (Page('Khadija Abdalla Bajaber'), 1283562354, Timestamp(2025, 4, 2, 7, 35, 49), 'I have added some information about her participation in Macondo Literature Festival 2024.')
# (Page('Khadija Abdalla Bajaber'), 1283557931, Timestamp(2025, 4, 2, 7, 3, 16), 'I have added a link to the article incase someone need to find  the work of Khadija Bajaber Enkare Review link')
# (Page('Talk:Lamu Fort Library'), 1276702571, Timestamp(2025, 2, 20, 8, 40, 20), '/* Proposed merger */ Reply')
# (Page('Siyu'), 1267232604, Timestamp(2025, 1, 4, 5, 20, 33), '/* See also */ I have added a Lamu Fort link')
# (Page('Lamu Fort'), 1267231770, Timestamp(2025, 1, 4, 5, 13, 34), 'I have added a citation of Lamu Fort Library')
# (Page('Lamu Fort Library'), 1267230760, Timestamp(2025, 1, 4, 5, 6, 27), '/* Library Services */  I have added a link of Lamu Maktaba ya sanaa')
# (Page('Lamu Fort Library'), 1267230555, Timestamp(2025, 1, 4, 5, 5, 13), '/* Maktaba ya Sanaa Section */  I have added a link of Lamu Maktaba ya sanaa to give information about the Lamu Maktaba ya Sanaa')
# (Page('Lamu Fort Library'), 1267228558, Timestamp(2025, 1, 4, 4, 54, 2), '/* Awards */ edit the invisible wikidata article')
# (Page('Lamu Fort Library'), 1267226894, Timestamp(2025, 1, 4, 4, 42, 21), 'I have added a link of Lamu Fort Librarian')
# (Page('Lamu Fort'), 1267224144, Timestamp(2025, 1, 4, 4, 24, 41), 'I have added a link of a Lamu Fort Library as a department of the Lamu Fort')
# (Page('Lamu Fort'), 1267222418, Timestamp(2025, 1, 4, 4, 12, 56), 'I have added a link of Lamu Fort Library on the Lamu Fort article to give information of the Lamu Fort Library as a department of the Lamu Fort')
# (Page('Lamu Fort'), 1267221346, Timestamp(2025, 1, 4, 4, 5, 34), 'I have added external link of Lamu Fort Library as a department of National Museums of Kenya Lamu Fort')
# (Page('Jamshid bin Abdullah'), 1266414128, Timestamp(2024, 12, 31, 13, 55, 28), '/* Biography */ I have added a citation on the Zanzibar revolution over Sultan Jamshid')
# (Page('Jamshid bin Abdullah'), 1266413260, Timestamp(2024, 12, 31, 13, 48, 3), '/* Biography */ I have added citation where needed on the Zanzibar revolution')
# (Page('Jamshid bin Abdullah'), 1266410068, Timestamp(2024, 12, 31, 13, 21, 4), '/* Biography */ I have added a link on the word sultan to let the people know the meaning of the sultan')
# (Page('Jamshid bin Abdullah'), 1266409630, Timestamp(2024, 12, 31, 13, 17, 3), '/* Biography */ I have added a link on the British protectorate, to explain the meaning of the British  protectorate for further study')
# (Page('Jamshid bin Abdullah'), 1266350623, Timestamp(2024, 12, 31, 5, 41, 24), '/* Death */ I have made some edits')
# (Page('Jamshid bin Abdullah'), 1266350312, Timestamp(2024, 12, 31, 5, 39, 30), '/* Death */ I have made some edits')
# (Page('Jamshid bin Abdullah'), 1266350082, Timestamp(2024, 12, 31, 5, 38, 8), '/* Death */ i have made some edit')
# (Page('Jamshid bin Abdullah'), 1266348452, Timestamp(2024, 12, 31, 5, 28, 33), '/* Death */ I have made some edits')
# (Page('Jamshid bin Abdullah'), 1266347593, Timestamp(2024, 12, 31, 5, 23, 32), '/* Ancestry */ I have added death information of the Sultan and the death heading')
# (Page('Istanbul Biennial'), 1265318513, Timestamp(2024, 12, 26, 9, 18, 54), '/* Past biennials */ I have made some edits')
# (Page('Istanbul Biennial'), 1265313425, Timestamp(2024, 12, 26, 8, 25, 4), '/* 18th Istanbul Biennial,2024 */ I have made some edits')
# (Page('Istanbul Biennial'), 1265313386, Timestamp(2024, 12, 26, 8, 24, 31), '/* Past participating artists */ I have added a list of curator on the participants list')
# (Page('Lydia Gatundu Galavu'), 1265312052, Timestamp(2024, 12, 26, 8, 11, 37), '/* Exhibitions */ I have added a link')
# (Page('Lydia Gatundu Galavu'), 1265303372, Timestamp(2024, 12, 26, 6, 54, 59), '/* Exhibitions */ I have added a link')
# (Page('Lydia Gatundu Galavu'), 1265303056, Timestamp(2024, 12, 26, 6, 52, 39), '/* Exhibitions */ I have added a link')
# (Page('Lydia Gatundu Galavu'), 1265302672, Timestamp(2024, 12, 26, 6, 50, 7), '/* Exhibitions */ I have added a link')
# (Page('Lydia Gatundu Galavu'), 1265302147, Timestamp(2024, 12, 26, 6, 46, 22), '/* Career */ I have made some edits')
# (Page('Lydia Gatundu Galavu'), 1265300769, Timestamp(2024, 12, 26, 6, 36, 42), '/* Career */ I have made some edits')
# (Page('Lydia Gatundu Galavu'), 1265300227, Timestamp(2024, 12, 26, 6, 32, 52), '/* Career */ I have made some edits')
# (Page('Lydia Gatundu Galavu'), 1265298799, Timestamp(2024, 12, 26, 6, 22, 4), '/* Exhibitions */ I have added some text')
# (Page('Lydia Gatundu Galavu'), 1265296694, Timestamp(2024, 12, 26, 6, 8, 34), '/* Exhibitions */ I have made some edits')
# (Page('Lydia Gatundu Galavu'), 1265164055, Timestamp(2024, 12, 25, 13, 1, 54), '/* Exhibitions */ I have made some edits')
# (Page('Lydia Gatundu Galavu'), 1265163702, Timestamp(2024, 12, 25, 12, 57, 46), '/* Exhibitions */ I have made some edits')
# (Page('Lydia Gatundu Galavu'), 1265163223, Timestamp(2024, 12, 25, 12, 53), '/* Exhibitions */ I have made some edits')

# %% [markdown]
# ## Aggregating the data
#
# Now let's start making a large data frame that contains all the edits for all the pages in this category. For now let's start by making a data frame for a single page - and then plot the contributions of users to it - both measured by number of submitted revisions and the total of added/removed characters.
#
# We start with a random page:

# %%
p = politician_pages[1]

# %% [markdown]
# Now we:
#
# 1. get all the revisions into a dataframe
# 2. then add the page title
# 3. calculate the size difference of the article, to evaluate how much text each edit added/removed

# %%
df = pd.DataFrame(p.revisions(content=True))
df['page_title'] = p.title() # add title which is missing from revisions
df['size_difference'] = df['size'] - df['size'].shift(periods=-1, fill_value=0) # add the size difference between each revision / previous state

# %% [markdown]
# ### Plotting the number of edits per editor

# %%
df.groupby(["user"]).count()['userid'].plot(kind='bar')
# Out:
# <Axes: xlabel='user'>

# %% [markdown]
# ### Plotting the overall size change made by the editor
#
# Note: A user could show up as "zero" edits, if they added and removed text of the same volume

# %%
df.groupby('user')['size_difference'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='user'>

# %% [markdown]
# ## Creating a `DataFrame` for all pages
#
# Now that we got a working code to create a `DataFrame` over all revisions of a single page, let's zoom one more step out - and create it for all pages in our category:

# %%
df_politicians = pd.DataFrame()

for p in politician_pages:
    df = pd.DataFrame(p.revisions(content=True))
    df['page_title'] = p.title() # add title which is missing from revisions
    df['size_difference'] = df['size'] - df['size'].shift(periods=-1, fill_value=0) # add the size difference between each revision / previous state 
    if not df_politicians.empty:
        df_politicians = pd.concat([df_politicians, df])
    else:
        df_politicians = df

df_politicians.head()

# %%
df_politicians.groupby(["page_title"]).count()['user'].plot(kind='bar',figsize=(30,10))
# Out:
#                       revid  parentid  minor  user  userid  timestamp  size  \
# page_title
# Aaron Cheruiyot          64        64     64    64      64         64    64
# Ababu Namwamba          179       179    179   179     179        179   179
# Abass Sheikh Mohamed     22        22     22    22      22         22    22
# Abdalla Mwidau           15        15     15    15      15         15    15
# Abdi Omar Shurie          9         9      9     9       9          9     9
# ...                     ...       ...    ...   ...     ...        ...   ...
# Zack Kìnùthia           139       139    139   139     139        139   139
# Zakayo Cheruiyot         72        72     72    72      72         72    72
# Zamzam Mohamed           10        10     10    10      10         10    10
# Zebedeo John Opore       46        46     46    46      46         46    46
# Zuleikha Hassan          30        30     30    30      30         30    30
#
#                       sha1  roles  slots  ...  tags  anon  userhidden  \
# page_title                                ...
# Aaron Cheruiyot         64     64     64  ...    64    64          64
# Ababu Namwamba         174    179    179  ...   179   179         179
# Abass Sheikh Mohamed    22     22     22  ...    22    22          22
# Abdalla Mwidau          15     15     15  ...    15    15          15
# Abdi Omar Shurie         9      9      9  ...     9     9           9
# ...                    ...    ...    ...  ...   ...   ...         ...
# Zack Kìnùthia          139    139    139  ...   139   139         139
# Zakayo Cheruiyot        72     72     72  ...    72    72          72
# Zamzam Mohamed          10     10     10  ...    10    10          10
# Zebedeo John Opore      46     46     46  ...    46    46          46
# Zuleikha Hassan         30     30     30  ...    30    30          30
#
#                       commenthidden  text  contentmodel  size_difference  \
# page_title
# Aaron Cheruiyot                  64    64            64               64
# Ababu Namwamba                  179   174           179              179
# Abass Sheikh Mohamed             22    22            22               22
# Abdalla Mwidau                   15    15            15               15
# Abdi Omar Shurie                  9     9             9                9
# ...                             ...   ...           ...              ...
# Zack Kìnùthia                   139   139           139              139
# Zakayo Cheruiyot                 72    72            72               72
# Zamzam Mohamed                   10    10            10               10
# Zebedeo John Opore               46    46            46               46
# Zuleikha Hassan                  30    30            30               30
#
#                       temp  sha1hidden  suppressed
# page_title
# Aaron Cheruiyot          0           0           0
# Ababu Namwamba           1           5           0
# Abass Sheikh Mohamed     0           0           0
# Abdalla Mwidau           2           0           0
# Abdi Omar Shurie         0           0           0
# ...                    ...         ...         ...
# Zack Kìnùthia            0           0           0
# Zakayo Cheruiyot         0           0           0
# Zamzam Mohamed           0           0           0
# Zebedeo John Opore       0           0           0
# Zuleikha Hassan          0           0           0
#
# [549 rows x 22 columns]
